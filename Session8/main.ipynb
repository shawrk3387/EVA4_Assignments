# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# setting project workspace

# %%
import sys
# sys.path.append('/content/gdrive/My Drive/Colab Notebooks/EVA4/session7')
sys.path.append('/content/gdrive/My Drive/EVA4_Session_8')

# %%
# !ls /content/gdrive/My\ Drive/Colab\ Notebooks/EVA4/session7/*.py
# !ls /content/gdrive/My\ Drive/EVA4_Session_8
# Out:
# dataloader  evaluation	main.ipynb  model  training

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary

from dataloader import dataset_loader
from model import model
from training import train
from evaluation import test

# %% [markdown]
# Loading data

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# setting up random seed and processing\ device
SEED = 1
cuda = torch.cuda.is_available()
if cuda:
    device = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    device = "cpu"
    torch.manual_seed(SEED)

# getting training data loader
trainloader = dataset_loader.get_dataloader(True, cuda)

# getting test data loader
testloader = dataset_loader.get_dataloader(False, cuda)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# initializing network architecture

# %%
# !pip install torchsummary
resnet18 = model.ResNet18().to(device)
print(summary(resnet18, input_size=(3, 32, 32)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------
# None

# %% [markdown]
# Model training and Evaluation

# %%
# loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet18.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005)

# Model Training and Evaluation
for epoch in range(0, 25):
    train.train(resnet18, device, trainloader, optimizer, epoch, criterion)
    test.test(resnet18, device, testloader, criterion)
# Out:
# epoch=0 Loss=1.3470406532287598 Batch_id=390 Accuracy=40.10: 100%|██████████| 391/391 [00:52<00:00,  7.42it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0107, Accuracy: 5077/10000 (50.8%)
# epoch=1 Loss=1.2130465507507324 Batch_id=390 Accuracy=56.26: 100%|██████████| 391/391 [00:53<00:00,  7.35it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0089, Accuracy: 5993/10000 (59.9%)
# epoch=2 Loss=0.7705143094062805 Batch_id=390 Accuracy=64.22: 100%|██████████| 391/391 [00:53<00:00,  7.31it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0081, Accuracy: 6466/10000 (64.7%)
# epoch=3 Loss=0.6960204839706421 Batch_id=390 Accuracy=69.08: 100%|██████████| 391/391 [00:53<00:00,  7.30it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0073, Accuracy: 6819/10000 (68.2%)
# epoch=4 Loss=0.7619005441665649 Batch_id=390 Accuracy=72.87: 100%|██████████| 391/391 [00:54<00:00,  7.22it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0063, Accuracy: 7205/10000 (72.0%)
# epoch=5 Loss=0.7660214900970459 Batch_id=390 Accuracy=75.93: 100%|██████████| 391/391 [00:54<00:00,  7.18it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0056, Accuracy: 7554/10000 (75.5%)
# epoch=6 Loss=0.6021276712417603 Batch_id=390 Accuracy=78.19: 100%|██████████| 391/391 [00:54<00:00,  7.23it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 7712/10000 (77.1%)
# epoch=7 Loss=0.5280601382255554 Batch_id=390 Accuracy=79.87: 100%|██████████| 391/391 [00:54<00:00,  7.20it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0050, Accuracy: 7895/10000 (79.0%)
# epoch=8 Loss=0.5239155292510986 Batch_id=390 Accuracy=81.55: 100%|██████████| 391/391 [00:54<00:00,  7.24it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.